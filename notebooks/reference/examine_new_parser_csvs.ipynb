# %%
import pandas as pd

# %%
df = pd.read_csv("../../csv/2018_03_01.csv")

# %%
df[df["train_id"] == "A20"]
# Out:
#      train_id        date  stop_sequence                 from  from_id  \
# 2112      A20  2018-03-01            NaN         Philadelphia        1
# 2113      A20  2018-03-01            NaN         Philadelphia        1
# 2114      A20  2018-03-01            NaN              Trenton      148
# 2115      A20  2018-03-01            NaN  Newark Penn Station      107
#
#                          to  to_id expected                 time    status  \
# 2112           Philadelphia      1      NaN  2018-03-01 12:09:13  departed
# 2113                Trenton    148      NaN  2018-03-01 14:15:15  departed
# 2114    Newark Penn Station    107      NaN  2018-03-01 14:59:15  departed
# 2115  New York Penn Station    105      NaN  2018-03-01 15:03:17  departed
#
#           line    type
# 2112  CRESCENT  Amtrak
# 2113  CRESCENT  Amtrak
# 2114  CRESCENT  Amtrak
# 2115  CRESCENT  Amtrak

# %%
df_new = pd.read_csv("../../csv/2018_03_02_with_update.csv")

# %%
df_new.head()
# Out:
#   train_id        date  stop_sequence                   from  from_id  \
# 0     5127  2018-03-02            1.0  New York Penn Station      105
# 1     5127  2018-03-02            2.0  New York Penn Station      105
# 2     5127  2018-03-02            3.0     Secaucus Upper Lvl    38187
# 3     5127  2018-03-02            4.0    Newark Penn Station      107
# 4     5127  2018-03-02            5.0                  Union    38105
#
#                       to  to_id             expected                 time  \
# 0  New York Penn Station    105  2018-03-02 13:47:00  2018-03-02 13:47:14
# 1     Secaucus Upper Lvl  38187  2018-03-02 13:56:00  2018-03-02 13:57:18
# 2    Newark Penn Station    107  2018-03-02 14:06:00  2018-03-02 14:05:19
# 3                  Union  38105  2018-03-02 14:15:00  2018-03-02 14:24:11
# 4           Roselle Park     31  2018-03-02 14:18:00  2018-03-02 14:27:18
#
#      status            line        type
# 0  departed  Raritan Valley  NJ Transit
# ...

# %%
df_newest = pd.read_csv("../../csv/2018_03_02.csv")

# %%
df_newest.head()
# Out:
#   train_id        date  stop_sequence                   from  from_id  \
# 0     5127  2018-03-02            1.0  New York Penn Station      105
# 1     5127  2018-03-02            2.0  New York Penn Station      105
# 2     5127  2018-03-02            3.0     Secaucus Upper Lvl    38187
# 3     5127  2018-03-02            4.0    Newark Penn Station      107
# 4     5127  2018-03-02            5.0                  Union    38105
#
#                       to  to_id             expected                 time  \
# 0  New York Penn Station    105  2018-03-02 13:47:00  2018-03-02 13:47:14
# 1     Secaucus Upper Lvl  38187  2018-03-02 13:56:00  2018-03-02 13:57:18
# 2    Newark Penn Station    107  2018-03-02 14:06:00  2018-03-02 14:05:19
# 3                  Union  38105  2018-03-02 14:15:00  2018-03-02 14:24:11
# 4           Roselle Park     31  2018-03-02 14:18:00  2018-03-02 14:27:18
#
#      status            line        type
# 0  departed  Raritan Valley  NJ Transit
# ...

# %%
df_old = pd.read_csv("../../csv/2018_03_02_check_only.csv")

# %%
df_old.head()
# Out:
#   train_id        date  stop_sequence                   from  from_id  \
# 0     5127  2018-03-02            1.0  New York Penn Station      105
# 1     5127  2018-03-02            2.0  New York Penn Station      105
# 2     5127  2018-03-02            3.0     Secaucus Upper Lvl    38187
# 3     5127  2018-03-02            4.0    Newark Penn Station      107
# 4     5127  2018-03-02            5.0                  Union    38105
#
#                       to  to_id             expected                 time  \
# 0  New York Penn Station    105  2018-03-02 13:47:00  2018-03-02 13:47:14
# 1     Secaucus Upper Lvl  38187  2018-03-02 13:56:00  2018-03-02 13:57:18
# 2    Newark Penn Station    107  2018-03-02 14:06:00  2018-03-02 14:05:19
# 3                  Union  38105  2018-03-02 14:15:00  2018-03-02 14:24:11
# 4           Roselle Park     31  2018-03-02 14:18:00  2018-03-02 14:27:18
#
#      status            line        type
# 0  departed  Raritan Valley  NJ Transit
# ...

# %%
merged = df_new.merge(df_old, indicator=True, how='outer')

# %%
merged["_merge"].unique()
# Out:
# [both, left_only, right_only]
# Categories (3, object): [both, left_only, right_only]

# %%
new_rows = merged[merged["_merge"] == "left_only"].copy()

# %%
old_rows = merged[merged["_merge"] == "right_only"].copy()

# %%
new_rows
# Out:
#      train_id        date  stop_sequence                   from  from_id  \
# 182     A2172  2018-03-02            NaN           Philadelphia        1
# 183     A2172  2018-03-02            NaN           Philadelphia        1
# 184     A2172  2018-03-02            NaN              Metropark       83
# 185     A2172  2018-03-02            NaN    Newark Penn Station      107
# 186     A2175  2018-03-02            NaN  New York Penn Station      105
# 187     A2175  2018-03-02            NaN  New York Penn Station      105
# 188     A2175  2018-03-02            NaN    Newark Penn Station      107
# 189     A2175  2018-03-02            NaN                Trenton      148
# 239      3279  2018-03-02            1.0  New York Penn Station      105
# 240      3279  2018-03-02            2.0  New York Penn Station      105
# 257      0053  2018-03-02            4.0                Suffern      144
# 314      A138  2018-03-02            NaN           Philadelphia        1
# ...

# %%
old_rows[(old_rows["status"] == "cancelled") & (old_rows["type"] == "NJ Transit")]
# Out:
#       train_id        date  stop_sequence                   from  from_id  \
# 10226     6359  2018-03-02            2.0  New York Penn Station      105
# 10227     6359  2018-03-02            3.0     Secaucus Upper Lvl    38187
# 10228     6359  2018-03-02            4.0    Newark Broad Street      106
# 10229     6359  2018-03-02            5.0           Brick Church       23
# 10230     6359  2018-03-02            6.0                 Orange      112
# 10231     6359  2018-03-02            7.0           South Orange      140
# 10232     6359  2018-03-02            8.0              Maplewood       81
# 10233     6359  2018-03-02            9.0               Millburn       87
# 10267     0267  2018-03-02            4.0      Watsessing Avenue      154
# 10268     0267  2018-03-02            5.0             Bloomfield       19
# 10269     0267  2018-03-02            6.0             Glen Ridge       50
# 10270     0267  2018-03-02            7.0             Bay Street       14
# ...

# %%
new_rows[new_rows["train_id"] == "6359"]
# Out:
#     train_id        date  stop_sequence                   from  from_id  \
# 502     6359  2018-03-02            1.0  New York Penn Station      105
# 503     6359  2018-03-02            2.0  New York Penn Station      105
# 504     6359  2018-03-02            3.0     Secaucus Upper Lvl    38187
# 505     6359  2018-03-02            4.0    Newark Broad Street      106
# 506     6359  2018-03-02            5.0           Brick Church       23
# 507     6359  2018-03-02            6.0                 Orange      112
# 508     6359  2018-03-02            7.0           South Orange      140
# 509     6359  2018-03-02            8.0              Maplewood       81
# 510     6359  2018-03-02            9.0               Millburn       87
#
#                         to  to_id             expected                 time  \
# 502  New York Penn Station    105  2018-03-02 18:50:00  2018-03-02 19:05:31
# 503     Secaucus Upper Lvl  38187  2018-03-02 18:59:00  2018-03-02 19:09:23
# ...

# %%
df_newest[df_newest["train_id"] == "6359"]
# Out:
#     train_id        date  stop_sequence                   from  from_id  \
# 502     6359  2018-03-02            1.0  New York Penn Station      105
# 503     6359  2018-03-02            2.0  New York Penn Station      105
# 504     6359  2018-03-02            3.0     Secaucus Upper Lvl    38187
# 505     6359  2018-03-02            4.0    Newark Broad Street      106
# 506     6359  2018-03-02            5.0           Brick Church       23
# 507     6359  2018-03-02            6.0                 Orange      112
# 508     6359  2018-03-02            7.0           South Orange      140
# 509     6359  2018-03-02            8.0              Maplewood       81
# 510     6359  2018-03-02            9.0               Millburn       87
#
#                         to  to_id             expected                 time  \
# 502  New York Penn Station    105  2018-03-02 18:50:00  2018-03-02 19:05:31
# 503     Secaucus Upper Lvl  38187  2018-03-02 18:59:00  2018-03-02 19:05:31
# ...

# %%
merged_new = df_newest.merge(df_new, indicator=True, how='outer')

# %%
newest_rows = merged_new[merged_new["_merge"] == "left_only"].copy()

# %%
newest_rows[(newest_rows["status"] != "estimated")]
# Out:
#      train_id        date  stop_sequence                   from  from_id  \
# 182     A2172  2018-03-02            NaN           Philadelphia        1
# 183     A2172  2018-03-02            NaN           Philadelphia        1
# 184     A2172  2018-03-02            NaN              Metropark       83
# 185     A2172  2018-03-02            NaN    Newark Penn Station      107
# 186     A2175  2018-03-02            NaN  New York Penn Station      105
# 187     A2175  2018-03-02            NaN  New York Penn Station      105
# 188     A2175  2018-03-02            NaN    Newark Penn Station      107
# 189     A2175  2018-03-02            NaN                Trenton      148
# 314      A138  2018-03-02            NaN           Philadelphia        1
# 315      A138  2018-03-02            NaN           Philadelphia        1
# 316      A138  2018-03-02            NaN                Trenton      148
# 317      A138  2018-03-02            NaN     Princeton Junction      125
# ...

# %%
df_new[df_new["train_id"] == "A2175"]
# Out:
#     train_id        date  stop_sequence                   from  from_id  \
# 186    A2175  2018-03-02            NaN  New York Penn Station      105
# 187    A2175  2018-03-02            NaN  New York Penn Station      105
# 188    A2175  2018-03-02            NaN    Newark Penn Station      107
# 189    A2175  2018-03-02            NaN                Trenton      148
#
#                         to  to_id expected                 time    status  \
# 186  New York Penn Station    105      NaN  2018-03-02 20:35:13  departed
# 187    Newark Penn Station    107      NaN  2018-03-02 21:06:10  departed
# 188                Trenton    148      NaN  2018-03-02 21:21:14  departed
# 189           Philadelphia      1      NaN  2018-03-02 21:52:10  departed
#
#               line    type
# 186  ACELA EXPRESS  Amtrak
# 187  ACELA EXPRESS  Amtrak
# 188  ACELA EXPRESS  Amtrak
# 189  ACELA EXPRESS  Amtrak

# %%
newest_rows
